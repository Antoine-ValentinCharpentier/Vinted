# %%
import pandas as pd

from dataprep_utils import merge_results
from display_graphs import display_unique_values

# %%
# df = merge_results('../data')
# Out:
# Files merged and saved inside ../data/merged_results.csv

# %%
df = pd.read_csv('../data/merged_results.csv', low_memory=False)

# %%
len(df)
# Out:
# 1157314

# %%
display_unique_values(df)
# Out:
# Number of unique values for 'title': 798695
# - Example of value : Badjas beertje paddington
# Number of unique values for 'url': 1141292
# - Example of value : https://www.vinted.fr/items/4802719647-badjas-beertje-paddington
# Number of unique values for 'photo': 1141267
# - Example of value : https://images1.vinted.net/t/03_010fa_ybV6B3GJer78k1icZgZXVtQW/f800/1721815053.jpeg?s=5f253d0b015b9a6655931f7ab336f34c104bd749
# Number of unique values for 'currency': 1
#  -> All values : ['EUR']
# Number of unique values for 'size_title': 295
# - Example of value : L / 40 / 12
# Number of unique values for 'status': 5
#  -> All values : ['Neuf sans étiquette' 'Très bon état' 'Bon état' 'Neuf avec étiquette'
#  'Satisfaisant']
# Number of unique values for 'brand_title': 71654
# - Example of value : Paddington
# Number of unique values for 'content_source': 2
#  -> All values : ['catalog' 'catalog_promoted_items']
# Number of unique values for 'user_url': 574239
# ...
